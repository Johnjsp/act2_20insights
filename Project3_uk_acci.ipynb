# %% [markdown]
# <h2>Importing Necessary Libraries</h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2>Converting data set to data frame</h2>

# %%
acci = pd.read_csv("C:\\Users\\coedy\\Downloads\\uk_road_accident.csv")

# %%
acci
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# <h2>Check Dataframe Information</h2>

# %%
acci.info
# Out:
# <bound method DataFrame.info of                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# <h2>Check Discriptive Statistics</h2>

# %%
acci.describe
# Out:
# <bound method NDFrame.describe of                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# <h2>Call Each Column Individually</h2>

# %%
acci['Index']
# Out:
# 0         200701BS64157
# 1         200701BS65737
# 2         200701BS66127
# 3         200701BS66128
# 4         200701BS66837
#               ...
# 660674    201091NM01760
# 660675    201091NM01881
# 660676    201091NM01935
# 660677    201091NM01964
# 660678    201091NM02142
# Name: Index, Length: 660679, dtype: object

# %%
acci['Accident_Severity']
# Out:
# 0         Serious
# 1         Serious
# 2         Serious
# 3         Serious
# 4          Slight
#            ...
# 660674     Slight
# 660675     Slight
# 660676     Slight
# 660677    Serious
# 660678    Serious
# Name: Accident_Severity, Length: 660679, dtype: object

# %%
acci['Accident Date']
# Out:
# 0           5/6/2019
# 1           2/7/2019
# 2         26-08-2019
# 3         16-08-2019
# 4           3/9/2019
#              ...
# 660674    18-02-2022
# 660675    21-02-2022
# 660676    23-02-2022
# 660677    23-02-2022
# 660678    28-02-2022
# Name: Accident Date, Length: 660679, dtype: object

# %%
acci['Latitude']
# Out:
# 0         51.506187
# 1         51.495029
# 2         51.517715
# 3         51.495478
# 4         51.488576
#             ...
# 660674    57.374005
# 660675    57.232273
# 660676    57.585044
# 660677    57.214898
# 660678    57.575210
# Name: Latitude, Length: 660679, dtype: float64

# %%
acci['Light_Conditions']
# Out:
# 0               Darkness - lights lit
# 1                            Daylight
# 2         Darkness - lighting unknown
# 3                            Daylight
# 4               Darkness - lights lit
#                      ...
# 660674                       Daylight
# 660675         Darkness - no lighting
# 660676                       Daylight
# 660677         Darkness - no lighting
# 660678                       Daylight
# Name: Light_Conditions, Length: 660679, dtype: object

# %%
acci['District Area']
# Out:
# 0         Kensington and Chelsea
# 1         Kensington and Chelsea
# 2         Kensington and Chelsea
# 3         Kensington and Chelsea
# 4         Kensington and Chelsea
#                    ...
# 660674                  Highland
# 660675                  Highland
# 660676                  Highland
# 660677                  Highland
# 660678                  Highland
# Name: District Area, Length: 660679, dtype: object

# %%
acci['Number_of_Casualties']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 660674    2
# 660675    1
# 660676    1
# 660677    1
# 660678    1
# Name: Number_of_Casualties, Length: 660679, dtype: int64

# %%
acci['Number_of_Vehicles']
# Out:
# 0         2
# 1         2
# 2         3
# 3         4
# 4         2
#          ..
# 660674    1
# 660675    1
# 660676    3
# 660677    2
# 660678    1
# Name: Number_of_Vehicles, Length: 660679, dtype: int64

# %%
acci['Road_Surface_Conditions']
# Out:
# 0                  Dry
# 1          Wet or damp
# 2                  Dry
# 3                  Dry
# 4                  Dry
#               ...
# 660674             Dry
# 660675    Frost or ice
# 660676    Frost or ice
# 660677     Wet or damp
# 660678     Wet or damp
# Name: Road_Surface_Conditions, Length: 660679, dtype: object

# %%
acci['Road_Type']
# Out:
# 0         Single carriageway
# 1         Single carriageway
# 2                        NaN
# 3         Single carriageway
# 4                        NaN
#                  ...
# 660674    Single carriageway
# 660675    Single carriageway
# 660676    Single carriageway
# 660677    Single carriageway
# 660678      Dual carriageway
# Name: Road_Type, Length: 660679, dtype: object

# %%
acci['Urban_or_Rural_Area']
# Out:
# 0         Urban
# 1         Urban
# 2         Urban
# 3         Urban
# 4         Urban
#           ...
# 660674    Rural
# 660675    Rural
# 660676    Rural
# 660677    Rural
# 660678    Rural
# Name: Urban_or_Rural_Area, Length: 660679, dtype: object

# %%
acci['Weather_Conditions']
# Out:
# 0            Fine no high winds
# 1         Raining no high winds
# 2                           NaN
# 3            Fine no high winds
# 4                           NaN
#                   ...
# 660674       Fine no high winds
# 660675       Fine no high winds
# 660676       Fine no high winds
# 660677       Fine no high winds
# 660678    Snowing no high winds
# Name: Weather_Conditions, Length: 660679, dtype: object

# %%
acci['Vehicle_Type']
# Out:
# 0                                          Car
# 1                                          Car
# 2                        Taxi/Private hire car
# 3         Bus or coach (17 or more pass seats)
# 4                                Other vehicle
#                           ...
# 660674                                     Car
# 660675                                     Car
# 660676                                     Car
# 660677                   Motorcycle over 500cc
# 660678                                     Car
# Name: Vehicle_Type, Length: 660679, dtype: object

# %% [markdown]
# <h2>Check For Null Values</h2>

# %%
acci.isnull()
# Out:
#         Index  Accident_Severity  Accident Date  Latitude  Light_Conditions  \
# 0       False              False          False     False             False
# 1       False              False          False     False             False
# 2       False              False          False     False             False
# 3       False              False          False     False             False
# 4       False              False          False     False             False
# ...       ...                ...            ...       ...               ...
# 660674  False              False          False     False             False
# 660675  False              False          False     False             False
# 660676  False              False          False     False             False
# 660677  False              False          False     False             False
# 660678  False              False          False     False             False
#
# ...

# %% [markdown]
# <h2>Fill Null Values with statistical values</h2>

# %%
acci['Accident_Severity'] = acci['Accident_Severity'].fillna(acci['Accident_Severity'].mode()[0])
acci['Light_Conditions'] = acci['Light_Conditions'].fillna(acci['Light_Conditions'].mode()[0])
acci['Road_Surface_Conditions'] = acci['Road_Surface_Conditions'].fillna(acci['Road_Surface_Conditions'].mode()[0])
acci['Number_of_Casualties'] = acci['Number_of_Casualties'].fillna(acci['Number_of_Casualties'].median())
acci['Number_of_Vehicles'] = acci['Number_of_Vehicles'].fillna(acci['Number_of_Vehicles'].median())
acci['District Area'] = acci['District Area'].fillna(acci['District Area'].mode()[0])

# %%
acci.isnull().sum
# Out:
# <bound method DataFrame.sum of         Index  Accident_Severity  Accident Date  Latitude  Light_Conditions  \
# 0       False              False          False     False             False
# 1       False              False          False     False             False
# 2       False              False          False     False             False
# 3       False              False          False     False             False
# 4       False              False          False     False             False
# ...       ...                ...            ...       ...               ...
# 660674  False              False          False     False             False
# 660675  False              False          False     False             False
# 660676  False              False          False     False             False
# 660677  False              False          False     False             False
# 660678  False              False          False     False             False
#
# ...

# %% [markdown]
# <h2>Extracting date information using pandas date time </h2>

# %%
acci['Accident Date'] = acci['Accident Date'].astype(str)
acci['Accident Date'] = acci['Accident Date'].apply(lambda x: x.replace('/', '-') if pd.notnull(x) else x)
acci['Accident Date'] = acci['Accident Date'].apply(lambda x: x.strip() if pd.notnull(x) else x)                                
acci['Accident Date'] = pd.to_datetime(acci['Accident Date'], dayfirst=True, errors='coerce')

acci.dtypes
acci.isnull().sum()

acci['Year'] = acci['Accident Date'].dt.year
acci['Month'] =  acci['Accident Date'].dt.month
acci['Day'] =  acci['Accident Date'].dt.day
acci['DayOfWeek'] =  acci['Accident Date'].dt.dayofweek
acci.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions        0
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# Year                           0
# Month                          0
# Day                            0
# DayOfWeek                      0
# dtype: int64

# %% [markdown]
# <h2>QUESTION 1. Which vehicle type has the most serious accidents </h2>

# %%
serious_vehicles = acci[acci["Accident_Severity"]=="Serious"]["Vehicle_Type"].value_counts()
serious_vehicles
# Out:
# Vehicle_Type
# Car                                      66461
# Van / Goods 3.5 tonnes mgw or under       4554
# Motorcycle over 500cc                     3457
# Bus or coach (17 or more pass seats)      3373
# Goods 7.5 tonnes mgw and over             2321
# Motorcycle 125cc and under                2031
# Taxi/Private hire car                     1771
# Motorcycle 50cc and under                 1014
# Motorcycle over 125cc and up to 500cc     1014
# Goods over 3.5t. and under 7.5t            857
# Other vehicle                              767
# Agricultural vehicle                       282
# Minibus (8 - 16 passenger seats)           276
# Pedal cycle                                 39
# Name: count, dtype: int64

# %% [markdown]
# <h2>1. INSIGHTS</h2>
# <p>It shows that cars has the most number of serious accidents</p>

# %% [markdown]
# <h2>Question 2. Which light condition records the highest average casualties? </h2>

# %%
avg_casualties_light = acci.groupby("Light_Conditions")["Number_of_Casualties"].mean()
avg_casualties_light
# Out:
# Light_Conditions
# Darkness - lighting unknown    1.306447
# Darkness - lights lit          1.369374
# Darkness - lights unlit        1.331105
# Darkness - no lighting         1.541657
# Daylight                       1.340309
# Name: Number_of_Casualties, dtype: float64

# %% [markdown]
# <h2>2. INSIGHTS</h2>
# <p>Night with poor lighting tends to have the highest casualties per accident.</p>

# %% [markdown]
# <h2>Question 3. Which weather condition has the highest average casualties in rural areas?</h2>

# %%
rural_weather_casualties = acci[acci["Urban_or_Rural_Area"]=="Rural"].groupby("Weather_Conditions")["Number_of_Casualties"].mean()
rural_weather_casualties
# Out:
# Weather_Conditions
# Fine + high winds        1.479589
# Fine no high winds       1.480076
# Fog or mist              1.513208
# Other                    1.423470
# Raining + high winds     1.485708
# Raining no high winds    1.513521
# Snowing + high winds     1.467601
# Snowing no high winds    1.401311
# Name: Number_of_Casualties, dtype: float64

# %% [markdown]
# <h2>3. INSIGHTS</h2>
# <p>Rural crashes in rainy or foggy conditions often result in higher casualties compared to clear weather.</p>

# %% [markdown]
# <h2>Question 4. What is the average vehicles per accident by severity? </h2>

# %%
avg_vehicles_severity = acci.groupby("Accident_Severity")["Number_of_Vehicles"].mean()
avg_vehicles_severity
# Out:
# Accident_Severity
# Fatal      1.786976
# Serious    1.678327
# Slight     1.855864
# Name: Number_of_Vehicles, dtype: float64

# %% [markdown]
# <h2>4. INSIGHTS</h2>
# <p>Fatal and serious accidents usually involve more vehicles than slight accidents.</p>

# %% [markdown]
# <h2>Question 5. What is total number of accidents recorded</h2>

# %%
total_acci = acci.shape[0]
total_acci
# Out:
# 660679

# %% [markdown]
# <h2>5. INSIGHTS</h2>
# <p>The total number of accidents is 660679</p>

# %% [markdown]
# <h2>Question 6. Which road surface has the highest average vehicles per accident?</h2>

# %%
avg_vehicles_surface = acci.groupby("Road_Surface_Conditions")["Number_of_Vehicles"].mean()
avg_vehicles_surface
# Out:
# Road_Surface_Conditions
# Dry                     1.841631
# Flood over 3cm. deep    1.610619
# Frost or ice            1.640006
# Snow                    1.746859
# Wet or damp             1.829161
# Name: Number_of_Vehicles, dtype: float64

# %% [markdown]
# <h2>6. INSIGHTS</h2>
# <p>Wet and icy surfaces often involve more multi-vehicle accidents compared to dry roads.</p>

# %% [markdown]
# <h2>Question 7. Which of the urban or rural has the most number of accidents?</h2>

# %%
urban_rural_counts = acci["Urban_or_Rural_Area"].value_counts()
urban_rural_counts
# Out:
# Urban_or_Rural_Area
# Urban          421663
# Rural          238990
# Unallocated        11
# Name: count, dtype: int64

# %% [markdown]
# <h2>7. INSIGHTS</h2>
# <p>Most accidents occur in urban areas, but rural crashes often involve higher casualties.</p>

# %% [markdown]
# <h2>Question 8. Which of the weather conditions has the number of accidetnts</h2>

# %%
weather_counts = acci["Weather_Conditions"].value_counts()
weather_counts
# Out:
# Weather_Conditions
# Fine no high winds       520885
# Raining no high winds     79696
# Other                     17150
# Raining + high winds       9615
# Fine + high winds          8554
# Snowing no high winds      6238
# Fog or mist                3528
# Snowing + high winds        885
# Name: count, dtype: int64

# %% [markdown]
# <h2>8. INSIGHTS</h2>
# <p>Most accidents happen in clear weather, but rain and fog increase accident severity.</p>

# %% [markdown]
# <h2>Question 9. Which light condition records the most accidents?</h2>

# %%
light_counts = acci["Light_Conditions"].value_counts()
light_counts
# Out:
# Light_Conditions
# Daylight                       484880
# Darkness - lights lit          129335
# Darkness - no lighting          37437
# Darkness - lighting unknown      6484
# Darkness - lights unlit          2543
# Name: count, dtype: int64

# %% [markdown]
# <h2>9. INSIGHTS</h2>
# <p>Most accidents happen in daylight, but nighttime accidents are more severe.</p>

# %% [markdown]
# <h2>Question 10. What vehicles types involved has the most number of accidents? </h2>

# %%
vehicle_counts = acci["Vehicle_Type"].value_counts()
vehicle_counts
# Out:
# Vehicle_Type
# Car                                      497992
# Van / Goods 3.5 tonnes mgw or under       34160
# Bus or coach (17 or more pass seats)      25878
# Motorcycle over 500cc                     25657
# Goods 7.5 tonnes mgw and over             17307
# Motorcycle 125cc and under                15269
# Taxi/Private hire car                     13294
# Motorcycle over 125cc and up to 500cc      7656
# Motorcycle 50cc and under                  7603
# Goods over 3.5t. and under 7.5t            6096
# Other vehicle                              5637
# Minibus (8 - 16 passenger seats)           1976
# Agricultural vehicle                       1947
# Pedal cycle                                 197
# Data missing or out of range                  6
# Ridden horse                                  4
# Name: count, dtype: int64

# %% [markdown]
# <h2>10. INSIGHTS</h2>
# <p>Cars are the most frequent vehicle type in accidents.</p>

# %% [markdown]
# <h2>QUESTION 11: What is the relationship between accident severity and light conditions?</h2>

# %%
severity_light =acci.groupby(["Accident_Severity","Light_Conditions"]).size()
severity_light
# Out:
# Accident_Severity  Light_Conditions
# Fatal              Darkness - lighting unknown        68
#                    Darkness - lights lit            1860
#                    Darkness - lights unlit            45
#                    Darkness - no lighting           1612
#                    Daylight                         5076
# Serious            Darkness - lighting unknown       794
#                    Darkness - lights lit           19130
#                    Darkness - lights unlit           360
#                    Darkness - no lighting           7174
#                    Daylight                        60759
# Slight             Darkness - lighting unknown      5622
#                    Darkness - lights lit          108345
#                    Darkness - lights unlit          2138
#                    Darkness - no lighting          28651
#                    Daylight                       419045
# dtype: int64

# %% [markdown]
# <h2> 11. INSIGHTS</h2>
# <p>Fatal and serious accidents occur more often in darkness than slight accidents, which dominate during daylight.</p>

# %% [markdown]
# <h2> QUESTION 12. What is the relationship between accident severity and road surface conditions?</h2>

# %%
severity_surface = acci.groupby(["Accident_Severity","Road_Surface_Conditions"]).size()
severity_surface
# Out:
# Accident_Severity  Road_Surface_Conditions
# Fatal              Dry                          5790
#                    Flood over 3cm. deep           23
#                    Frost or ice                  193
#                    Snow                           35
#                    Wet or damp                  2620
# Serious            Dry                         61708
#                    Flood over 3cm. deep          152
#                    Frost or ice                 2007
#                    Snow                          565
#                    Wet or damp                 23785
# Slight             Dry                        381049
#                    Flood over 3cm. deep          842
#                    Frost or ice                16317
#                    Snow                         5290
#                    Wet or damp                160303
# dtype: int64

# %% [markdown]
# <h2>12. INSIGHTS </h2>
# <p>Slight accidents dominate dry roads, but fatal accidents are more frequent (proportionally) on wet, icy, or snowy surfaces.</p>

# %% [markdown]
# <h2>QUESTION 13. What is the Correlation between number of vehicles and casualties?</h2>

# %%
corr = acci[["Number_of_Vehicles", "Number_of_Casualties"]].corr()
corr
# Out:
#                       Number_of_Vehicles  Number_of_Casualties
# Number_of_Vehicles              1.000000              0.228889
# Number_of_Casualties            0.228889              1.000000

# %% [markdown]
# <h2>13. INSIGHTS</h2>
# <p>A positive correlation means more vehicles usually result in more casualties.</p>

# %% [markdown]
# <h2>QUESTION 14. Which accident severity has the highest average number of vehicles involved?</h2>

# %%
avg_vehicles_by_severity = acci.groupby("Accident_Severity")["Number_of_Vehicles"].mean()
avg_vehicles_by_severity
# Out:
# Accident_Severity
# Fatal      1.786976
# Serious    1.678327
# Slight     1.855864
# Name: Number_of_Vehicles, dtype: float64

# %% [markdown]
# <h2>14. INSIGHT</h2>
# <p>Serious accidents tend to involve more vehicles compared to slight ones</p>

# %% [markdown]
# <h2>QUESTION 15. WHICH OF THE ROAD TYPES HAS THE MOSE COUNTS OF ACCIDENTS</h2>

# %%
road_type_counts = acci["Road_Type"].value_counts()
road_type_counts
# Out:
# Road_Type
# Single carriageway    492143
# Dual carriageway       99424
# Roundabout             43992
# One way street         13559
# Slip road               7041
# Name: count, dtype: int64

# %% [markdown]
# <h2>15. INSIGHTS</h2>
# <p>Most accidents occur on single carriageways, followed by dual carriageways.</p>

# %% [markdown]
# <h2>QUESTION 16. Which weather condition has the highest proportion of fatal accidents?</h2>

# %%
fatal_rate_weather = acci[acci["Accident_Severity"]=="Fatal"].groupby("Weather_Conditions").size() / acci.groupby("Weather_Conditions").size()
fatal_rate_weather
# Out:
# Weather_Conditions
# Fine + high winds        0.020458
# Fine no high winds       0.013631
# Fog or mist              0.023243
# Other                    0.009621
# Raining + high winds     0.015081
# Raining no high winds    0.010640
# Snowing + high winds     0.003390
# Snowing no high winds    0.005771
# dtype: float64

# %% [markdown]
# <h2>16. INSIGHTS</h2>
# <p>
# Although most accidents happen in clear weather, the proportion of fatal crashes is higher in fog/rain conditions.</p>

# %% [markdown]
# <h2>QUESTION 17. What is the average number of casualties per accident severity by area type (urban/rural) </h2>

# %%
avg_casualties_severity_area = acci.groupby(["Urban_or_Rural_Area","Accident_Severity"])["Number_of_Casualties"].mean()
avg_casualties_severity_area
# Out:
# Urban_or_Rural_Area  Accident_Severity
# Rural                Fatal                2.094804
#                      Serious              1.682301
#                      Slight               1.422972
# Unallocated          Serious              1.000000
#                      Slight               1.200000
# Urban                Fatal                1.552288
#                      Serious              1.309693
#                      Slight               1.282586
# Name: Number_of_Casualties, dtype: float64

# %% [markdown]
# <h2>17. INSIGHTS</h2>
# <p> it shows that fatal rural accidents tend to involve more casualties compared to fatal urban ones.</p>

# %% [markdown]
# <h2> QUESTION 18. Which District with the most recorded accidents
# </h2>

# %%
most_accidents_district = acci["District Area"].value_counts()
most_accidents_district
# Out:
# District Area
# Birmingham            13491
# Leeds                  8898
# Manchester             6720
# Bradford               6212
# Sheffield              5710
#                       ...
# Berwick-upon-Tweed      153
# Teesdale                142
# Shetland Islands        133
# Orkney Islands          117
# Clackmannanshire         91
# Name: count, Length: 422, dtype: int64

# %% [markdown]
# <h2>18. INSIGHTS </h2>
# <p>It shows that the Birmingham the most record of accidents</p>

# %% [markdown]
# <h2>QUESTION 19. What is the most common road surface condition in fatal accidents</h2>

# %%
fatal_surface = acci[acci["Accident_Severity"]=="Fatal"]["Road_Surface_Conditions"].value_counts()
fatal_surface
# Out:
# Road_Surface_Conditions
# Dry                     5790
# Wet or damp             2620
# Frost or ice             193
# Snow                      35
# Flood over 3cm. deep      23
# Name: count, dtype: int64

# %% [markdown]
# <h2>19. INSIGHTS </h2>
# <p>It shows that the most common road surface to have a fatal accidents is DRY surface.</p>

# %% [markdown]
# <h2>QUESTION 20. Which district has the lowest number of recorded accidents?</h2>

# %%
lowest_district = acci["District Area"].value_counts()
lowest_district
# Out:
# District Area
# Birmingham            13491
# Leeds                  8898
# Manchester             6720
# Bradford               6212
# Sheffield              5710
#                       ...
# Berwick-upon-Tweed      153
# Teesdale                142
# Shetland Islands        133
# Orkney Islands          117
# Clackmannanshire         91
# Name: count, Length: 422, dtype: int64

# %% [markdown]
# <h2>20. INSIGHTS</h2>
# <p>It shows that the Clackmannanshire has the lowest record of accidents </p>

# %% [markdown]
# <h2>QUESTION 21. Which year had the most accidents?</h2>

# %%
accidents_per_year = acci["Accident Date"].dt.year.value_counts().sort_index()
accidents_per_year.plot(kind="bar", color="teal", edgecolor="black")
plt.title("Accidents per Year")
plt.xlabel("Year")
plt.ylabel("Number of Accidents")
plt.show()

# %% [markdown]
# <h2>21 INSIGHTS.</h2>
# <p>It shows that the most count year accidents is 2019 and the least number of accidents is on 2022</p>

# %% [markdown]
# <h2>QUESTION 22. Which month records the most accidents?</h2>

# %%
accidents_per_month = acci["Accident Date"].dt.month.value_counts().sort_index()
accidents_per_month.plot(kind="line", marker="o", color="blue")
plt.title("Accidents per Month")
plt.xlabel("Month")
plt.ylabel("Number of Accidents")
plt.show()

# %% [markdown]
# <h2>22. INSIGHTS</h2>
# <p>In this graph, it shows most count of accidents is 12 means it's december, and the least number of count of accidents is the 2 which is Febraury</p>

# %% [markdown]
# <h2>Question 23. At what time of day do most accidents occur?</h2>

# %%
accidents_per_hour = acci["Accident Date"].dt.hour.value_counts().sort_index()
accidents_per_hour.plot(kind="line", marker="o", color="red")
plt.title("Accidents by Hour of the Day")
plt.xlabel("Hour")
plt.ylabel("Number of Accidents")
plt.show()

# %% [markdown]
# <h2>23. INSIGHTS</h2>
# <p>Accidents peak during rush hours (8–9 AM, 5–7 PM) when traffic volume is highest.</p>

# %% [markdown]
# <h2>Question 24. Most common accident severity by light condition </h2>

# %%
severity_light = acci.groupby("Light_Conditions")["Accident_Severity"].value_counts().unstack().fillna(0)
severity_light.plot(kind="bar", stacked=True, figsize=(8,5))
plt.title("Accident Severity by Light Condition")
plt.xlabel("Light Condition")
plt.ylabel("Number of Accidents")
plt.xticks(rotation=30)
plt.legend(title="Severity")
plt.show()

# %% [markdown]
# <h2>24 INSIGHTS. </h2>
# <p>Serious/fatal accidents may be more frequent at night compared to daylight.</p>

# %% [markdown]
# <h2>Question 25. What is most count of accidents by Day of the Week  </h2>

# %%
day_map = {
    1: "Monday", 2: "Tuesday", 3: "Wednesday",
    4: "Thursday", 5: "Friday", 6: "Saturday", 7: "Sunday"
}

day_counts = acci["DayOfWeek"].map(day_map).value_counts()

plt.pie(day_counts, labels=day_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Accidents by Day of the Week")
plt.show()

# %% [markdown]
# <h2>25 INSIGHTS.</h2>
# <p>This will clearly show which days Friday evenings or weekends contribute most to accidents, instead of just numbers.</p>

# %%
acci['District Area'].unique()
# Out:
# array(['Kensington and Chelsea', 'Westminster', 'Richmond upon Thames',
#        'Hammersmith and Fulham', 'Hounslow', 'Tower Hamlets',
#        'City of London', 'Southwark', 'Camden', 'Hackney', 'Islington',
#        'Barnet', 'Brent', 'Haringey', 'Merton', 'Ealing', 'Enfield',
#        'Greenwich', 'Newham', 'London Airport (Heathrow)', 'Hillingdon',
#        'Waltham Forest', 'Redbridge', 'Barking and Dagenham', 'Bromley',
#        'Havering', 'Croydon', 'Lambeth', 'Wandsworth', 'Sutton', 'Bexley',
#        'Lewisham', 'Harrow', 'Kingston upon Thames', 'Barrow-in-Furness',
#        'South Lakeland', 'Carlisle', 'Eden', 'Allerdale', 'Copeland',
#        'Fylde', 'Blackpool', 'Wyre', 'Lancaster', 'Chorley',
#        'West Lancashire', 'South Ribble', 'Preston',
#        'Blackburn with Darwen', 'Hyndburn', 'Ribble Valley', 'Burnley',
#        'Pendle', 'Rossendale', 'Wirral', 'Liverpool', 'Sefton',
#        'Knowsley', 'St. Helens', 'Manchester', 'Salford', 'Tameside',
# ...

# %% [markdown]
# <h2>Stafford Accidents per year</h2>

# %%
london_df = acci[acci['District Area'] == 'Stafford']

# %%
accidents_per_year = london_df['Year'].value_counts().sort_index()
accidents_per_month = london_df['Month'].value_counts().sort_index()
accidents_per_day = london_df['DayOfWeek'].value_counts().sort_index()


#PER YEAR 
accidents_per_year.plot(kind='bar')
plt.title('City of Stafford accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

# %% [markdown]
# <h2>Monthly Road Accidents in Luton city of London by Year (2019-2022)</h2>

# %%
london_df = acci[acci['District Area'] == 'Luton']

# %%
monthly_Luton = london_df.groupby(['Year', 'Month']).size()

monthly_Luton = monthly_Luton.unstack(level=0)

monthly_Luton.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Luton city of London by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# <h2>Accidents by day of the week of Plymouth city of london</h2>

# %%
london_df = acci[acci['District Area'] == 'Plymouth']

# %%
day_map = {
    1: "Monday", 2: "Tuesday", 3: "Wednesday",
    4: "Thursday", 5: "Friday", 6: "Saturday", 7: "Sunday"
}

day_counts = london_df["DayOfWeek"].map(day_map).value_counts()

plt.pie(day_counts, labels=day_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Accidents by day of the week of Plymouth city of london")
plt.show()

# %% [markdown]
# <h2>Project #3</h2>

# %% [markdown]
# <h2>Part 1. "Analyzing District Area in relation to the general outcome"</h2>
# <h2>PLYMOUTH ANALYSIS</h2>

# %%
Plymouth_df = acci[acci['District Area'] == 'Plymouth']

# %%
import folium
from folium.plugins import HeatMap

# Create list of coordinates
locations = list(zip(Plymouth_df['Latitude'], london_df['Longitude']))

# Initialize map at mean location
m = folium.Map(
    location=[Plymouth_df['Latitude'].mean(), london_df['Longitude'].mean()],
    zoom_start=10
)

# Add HeatMap
HeatMap(locations).add_to(m)

# Show map directly in Jupyter
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
accidents_per_year = Plymouth_df['Year'].value_counts().sort_index()
accidents_per_month = Plymouth_df['Month'].value_counts().sort_index()
accidents_per_day = Plymouth_df['DayOfWeek'].value_counts().sort_index()
 
accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       281
# Tuesday      418
# Wednesday    437
# Thursday     452
# Friday       528
# Saturday     522
# Sunday       387
# Name: count, dtype: int64

# %%
monthly_londondata = Plymouth_df.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Plymouth by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
day_map = {
    1: "Monday", 2: "Tuesday", 3: "Wednesday",
    4: "Thursday", 5: "Friday", 6: "Saturday", 7: "Sunday"
}

day_counts = Plymouth_df["DayOfWeek"].map(day_map).value_counts()

plt.pie(day_counts, labels=day_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Weekly road accidents in Plymouth of london")
plt.show()

# %% [markdown]
# <h2>Part 2. "Analyzing District Area in relation to the general outcome" </h2>
# <h2>STAFFORD ANALYSIS</h2>

# %%
Stafford_df = acci[acci['District Area'] == 'Stafford']

# %%
import folium
from folium.plugins import HeatMap

# Create list of coordinates
locations = list(zip(Stafford_df['Latitude'], Stafford_df['Longitude']))

# Initialize map at mean location
m = folium.Map(
    location=[Stafford_df['Latitude'].mean(), Stafford_df['Longitude'].mean()],
    zoom_start=10
)

# Add HeatMap
HeatMap(locations).add_to(m)

# Show map directly in Jupyter
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
Stafford_df = acci[acci['District Area'] == 'Stafford']

# %%
monthly_londondata = Stafford_df.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Stafford by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
day_map = {
    1: "Monday", 2: "Tuesday", 3: "Wednesday",
    4: "Thursday", 5: "Friday", 6: "Saturday", 7: "Sunday"
}

day_counts = Stafford_df["DayOfWeek"].map(day_map).value_counts()

plt.pie(day_counts, labels=day_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Weekly road accidents in Stafford city of london")
plt.show()

# %% [markdown]
# <h2>PART 3.  "Analyzing District Area in relation to the general outcome" </h2>
# <h2>ROCHFORD ANALYSIS</h2>

# %%
Rochford_df = acci[acci['District Area'] == 'Rochford']

# %%
import folium
from folium.plugins import HeatMap

# Create list of coordinates
locations = list(zip(Rochford_df['Latitude'], Rochford_df['Longitude']))

# Initialize map at mean location
m = folium.Map(
    location=[Rochford_df['Latitude'].mean(), Rochford_df['Longitude'].mean()],
    zoom_start=10
)

# Add HeatMap
HeatMap(locations).add_to(m)

# Show map directly in Jupyter
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
monthly_londondata = Rochford_df.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Rochford by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
accidents_per_year = Rochford_df['Year'].value_counts().sort_index()
accidents_per_month = Rochford_df['Month'].value_counts().sort_index()
accidents_per_day = Rochford_df['DayOfWeek'].value_counts().sort_index()
 
accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday        77
# Tuesday       95
# Wednesday    104
# Thursday      95
# Friday       105
# Saturday     103
# Sunday        96
# Name: count, dtype: int64

# %%
day_map = {
    1: "Monday", 2: "Tuesday", 3: "Wednesday",
    4: "Thursday", 5: "Friday", 6: "Saturday", 7: "Sunday"
}

day_counts = Stafford_df["DayOfWeek"].map(day_map).value_counts()

plt.pie(day_counts, labels=day_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Weekly road accidents in Rochford of london")
plt.show()

# %% [markdown]
# <h2>Part 4. "Analyzing District Area in relation to the general outcome" </h2>
# <h2>WILTSHIRE ANALYSIS</h2>

# %%
Wiltshire_df = acci[acci['District Area'] == 'Wiltshire']

# %%
import folium
from folium.plugins import HeatMap

# Create list of coordinates
locations = list(zip(Wiltshire_df ['Latitude'], Wiltshire_df ['Longitude']))

# Initialize map at mean location
m = folium.Map(
    location=[Wiltshire_df ['Latitude'].mean(), Wiltshire_df ['Longitude'].mean()],
    zoom_start=10
)

# Add HeatMap
HeatMap(locations).add_to(m)

# Show map directly in Jupyter
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
accidents_per_year = Wiltshire_df['Year'].value_counts().sort_index()
accidents_per_month = Wiltshire_df['Month'].value_counts().sort_index()
accidents_per_day = Wiltshire_df['DayOfWeek'].value_counts().sort_index()
 
accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       183
# Tuesday      226
# Wednesday    233
# Thursday     237
# Friday       223
# Saturday     272
# Sunday       216
# Name: count, dtype: int64

# %%
monthly_londondata = Wiltshire_df.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Wiltshire by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
day_map = {
    1: "Monday", 2: "Tuesday", 3: "Wednesday",
    4: "Thursday", 5: "Friday", 6: "Saturday", 7: "Sunday"
}

day_counts = Wiltshire_df["DayOfWeek"].map(day_map).value_counts()

plt.pie(day_counts, labels=day_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Weekly road accidents in Wiltshire of london")
plt.show()

# %% [markdown]
# <h2>Part 5. "Analyzing District Area in relation to the general outcome" </h2>
# <h2>DUNDEE CITY ANALYSIS</h2>

# %%
DundeeCity_df = acci[acci['District Area'] == 'Dundee City']

# %%
import folium
from folium.plugins import HeatMap

# Create list of coordinates
locations = list(zip(DundeeCity_df['Latitude'], DundeeCity_df ['Longitude']))

# Initialize map at mean location
m = folium.Map(
    location=[DundeeCity_df ['Latitude'].mean(), DundeeCity_df ['Longitude'].mean()],
    zoom_start=10
)

# Add HeatMap
HeatMap(locations).add_to(m)

# Show map directly in Jupyter
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
accidents_per_year = DundeeCity_df['Year'].value_counts().sort_index()
accidents_per_month = DundeeCity_df['Month'].value_counts().sort_index()
accidents_per_day = DundeeCity_df['DayOfWeek'].value_counts().sort_index()
 
accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday        81
# Tuesday      117
# Wednesday    133
# Thursday     116
# Friday       109
# Saturday     143
# Sunday       100
# Name: count, dtype: int64

# %%
monthly_londondata = DundeeCity_df.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Dundee City by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
day_map = {
    1: "Monday", 2: "Tuesday", 3: "Wednesday",
    4: "Thursday", 5: "Friday", 6: "Saturday", 7: "Sunday"
}

day_counts = DundeeCity_df["DayOfWeek"].map(day_map).value_counts()

plt.pie(day_counts, labels=day_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Weekly road accidents in Dundee City of london")
plt.show()

# %% [markdown]
# <h2>Part 6. "Analyzing District Area in relation to the general outcome" </h2>
# <h2>ANGUS ANALYSIS</h2>

# %%
Angus_df = acci[acci['District Area'] == 'Angus']

# %%
import folium
from folium.plugins import HeatMap

# Create list of coordinates
locations = list(zip(Angus_df['Latitude'], Angus_df ['Longitude']))

# Initialize map at mean location
m = folium.Map(
    location=[Angus_df ['Latitude'].mean(), Angus_df ['Longitude'].mean()],
    zoom_start=10
)

# Add HeatMap
HeatMap(locations).add_to(m)

# Show map directly in Jupyter
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
accidents_per_year = Angus_df['Year'].value_counts().sort_index()
accidents_per_month = Angus_df['Month'].value_counts().sort_index()
accidents_per_day = Angus_df['DayOfWeek'].value_counts().sort_index()
 
accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()

day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday        92
# Tuesday      109
# Wednesday    103
# Thursday     134
# Friday       117
# Saturday     141
# Sunday       100
# Name: count, dtype: int64

# %%
monthly_londondata = Angus_df.groupby(['Year', 'Month', ]).size()

monthly_londondata = monthly_londondata.unstack(level=0)

monthly_londondata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Angus by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
day_map = {
    1: "Monday", 2: "Tuesday", 3: "Wednesday",
    4: "Thursday", 5: "Friday", 6: "Saturday", 7: "Sunday"
}

day_counts = Angus_df["DayOfWeek"].map(day_map).value_counts()

plt.pie(day_counts, labels=day_counts.index, autopct="%1.1f%%", startangle=90)
plt.title("Weekly road accidents in Angus City of london")
plt.show()

# %% [markdown]
# <h2> MIDTERMS HANDSON EXAM ( CHICAGO CRIME REPORT )</h2>

# %% [markdown]
# <h2>ANALYST: JOHN JOSEPH ISRAEL </h2>

# %% [markdown]
# <h2>Converting data set to data frame</h2>

# %%
crime = pd.read_csv("C:\\Users\\coedy\\Downloads\\Chicago_Crimes.csv")

# %%
crime
# Out:
#               ID Case Number                    Date                  Block  \
# 0       13439321    JH237424  04/14/2024 12:00:00 AM    040XX S PRAIRIE AVE
# 1       13437420    JH234779  04/14/2024 12:00:00 AM      023XX W CERMAK RD
# 2       13428676    JH224478  04/14/2024 12:00:00 AM    043XX W LE MOYNE ST
# 3       13429357    JH225293  04/14/2024 12:00:00 AM       039XX W ADAMS ST
# 4       13430098    JH226395  04/14/2024 12:00:00 AM       011XX W 112TH PL
# ...          ...         ...                     ...                    ...
# 249118  13805239    JJ217509  04/12/2025 12:00:00 AM     029XX W LOGAN BLVD
# 249119  13804023    JJ215813  04/12/2025 12:00:00 AM    094XX S HARVARD AVE
# 249120  13803926    JJ215943  04/12/2025 12:00:00 AM  084XX S VINCENNES AVE
# 249121  13803475    JJ215338  04/12/2025 12:00:00 AM    050XX S ABERDEEN ST
# 249122  13804512    JJ216668  04/12/2025 12:00:00 AM    012XX W CARROLL AVE
#
# ...

# %% [markdown]
# <h2>Check Dataframe Information</h2>

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249123 entries, 0 to 249122
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    249123 non-null  int64
#  1   Case Number           249123 non-null  object
#  2   Date                  249123 non-null  object
#  3   Block                 249123 non-null  object
#  4   IUCR                  249123 non-null  object
#  5   Primary Type          249123 non-null  object
#  6   Description           249123 non-null  object
#  7   Location Description  248266 non-null  object
#  8   Arrest                249123 non-null  bool
#  9   Domestic              249123 non-null  bool
#  10  Beat                  249123 non-null  int64
#  11  District              249123 non-null  int64
#  12  Ward                  249123 non-null  int64
#  13  Community Area        249120 non-null  float64
# ...

# %% [markdown]
# <h2>Check Discriptive Statistics</h2>

# %%
crime.describe()
# Out:
#                  ID           Beat       District           Ward  \
# count  2.491230e+05  249123.000000  249123.000000  249123.000000
# mean   1.358652e+07    1153.845634      11.308924      23.186823
# std    6.473192e+05     707.959752       7.074807      13.925951
# min    2.807300e+04     111.000000       1.000000       1.000000
# 25%    1.352322e+07     533.000000       5.000000      10.000000
# 50%    1.361560e+07    1034.000000      10.000000      23.000000
# 75%    1.370865e+07    1732.000000      17.000000      34.000000
# max    1.381045e+07    2535.000000      31.000000      50.000000
#
#        Community Area  X Coordinate  Y Coordinate           Year  \
# count   249120.000000  2.490330e+05  2.490330e+05  249123.000000
# mean        36.238560  1.165309e+06  1.887602e+06    2024.241668
# std         21.567485  1.616814e+04  3.146277e+04       0.428095
# min          1.000000  1.092647e+06  1.813897e+06    2024.000000
# ...

# %% [markdown]
# <h2>Call Each Column Individually</h2>

# %%
crime['ID']
# Out:
# 0         13439321
# 1         13437420
# 2         13428676
# 3         13429357
# 4         13430098
#             ...
# 249118    13805239
# 249119    13804023
# 249120    13803926
# 249121    13803475
# 249122    13804512
# Name: ID, Length: 249123, dtype: int64

# %%
crime['Beat']
# Out:
# 0          213
# 1         1034
# 2         2534
# 3         1122
# 4         2234
#           ...
# 249118    1414
# 249119     634
# 249120     622
# 249121     933
# 249122    1215
# Name: Beat, Length: 249123, dtype: int64

# %%
crime['District']
# Out:
# 0          2
# 1         10
# 2         25
# 3         11
# 4         22
#           ..
# 249118    14
# 249119     6
# 249120     6
# 249121     9
# 249122    12
# Name: District, Length: 249123, dtype: int64

# %%
crime['Ward']
# Out:
# 0          3
# 1         25
# 2         36
# 3         28
# 4         21
#           ..
# 249118     1
# 249119     9
# 249120    21
# 249121    20
# 249122    27
# Name: Ward, Length: 249123, dtype: int64

# %%
crime['Community Area']
# Out:
# 0         38.0
# 1         31.0
# 2         23.0
# 3         26.0
# 4         75.0
#           ...
# 249118    22.0
# 249119    49.0
# 249120    71.0
# 249121    61.0
# 249122    28.0
# Name: Community Area, Length: 249123, dtype: float64

# %%
crime['X Coordinate']
# Out:
# 0         1178707.0
# 1         1161210.0
# 2         1146960.0
# 3         1150158.0
# 4         1170856.0
#             ...
# 249118    1156478.0
# 249119    1175694.0
# 249120    1173850.0
# 249121    1169838.0
# 249122    1168216.0
# Name: X Coordinate, Length: 249123, dtype: float64

# %%
crime['Y Coordinate']
# Out:
# 0         1878256.0
# 1         1889347.0
# 2         1909501.0
# 3         1898721.0
# 4         1830157.0
#             ...
# 249118    1917149.0
# 249119    1842631.0
# 249120    1848976.0
# 249121    1871348.0
# 249122    1902390.0
# Name: Y Coordinate, Length: 249123, dtype: float64

# %%
crime['Year']
# Out:
# 0         2024
# 1         2024
# 2         2024
# 3         2024
# 4         2024
#           ...
# 249118    2025
# 249119    2025
# 249120    2025
# 249121    2025
# 249122    2025
# Name: Year, Length: 249123, dtype: int64

# %%
crime['Latitude']
# Out:
# 0         41.821236
# 1         41.852052
# 2         41.907640
# 3         41.877997
# 4         41.689421
#             ...
# 249118    41.928440
# 249119    41.723545
# 249120    41.740998
# 249121    41.802477
# 249122    41.887694
# Name: Latitude, Length: 249123, dtype: float64

# %%
crime['Longitude']
# Out:
# 0        -87.619921
# 1        -87.683801
# 2        -87.735587
# 3        -87.724121
# 4        -87.650123
#             ...
# 249118   -87.700416
# 249119   -87.632040
# 249120   -87.638606
# 249121   -87.652657
# 249122   -87.657710
# Name: Longitude, Length: 249123, dtype: float64

# %%
crime['Primary Type']
# Out:
# 0                       THEFT
# 1               OTHER OFFENSE
# 2         MOTOR VEHICLE THEFT
# 3           WEAPONS VIOLATION
# 4                       THEFT
#                  ...
# 249118          OTHER OFFENSE
# 249119                BATTERY
# 249120                BATTERY
# 249121                ASSAULT
# 249122                  THEFT
# Name: Primary Type, Length: 249123, dtype: object

# %%
crime['Description']
# Out:
# 0                               FROM BUILDING
# 1                     HARASSMENT BY TELEPHONE
# 2               CYCLE, SCOOTER, BIKE WITH VIN
# 3               UNLAWFUL POSSESSION - HANDGUN
# 4                               FROM BUILDING
#                          ...
# 249118         HARASSMENT BY ELECTRONIC MEANS
# 249119    AGGRAVATED - OTHER DANGEROUS WEAPON
# 249120                DOMESTIC BATTERY SIMPLE
# 249121    AGGRAVATED - OTHER DANGEROUS WEAPON
# 249122               THEFT FROM MOTOR VEHICLE
# Name: Description, Length: 249123, dtype: object

# %%
crime['Block']
# Out:
# 0           040XX S PRAIRIE AVE
# 1             023XX W CERMAK RD
# 2           043XX W LE MOYNE ST
# 3              039XX W ADAMS ST
# 4              011XX W 112TH PL
#                   ...
# 249118       029XX W LOGAN BLVD
# 249119      094XX S HARVARD AVE
# 249120    084XX S VINCENNES AVE
# 249121      050XX S ABERDEEN ST
# 249122      012XX W CARROLL AVE
# Name: Block, Length: 249123, dtype: object

# %%
crime['Case Number']
# Out:
# 0         JH237424
# 1         JH234779
# 2         JH224478
# 3         JH225293
# 4         JH226395
#             ...
# 249118    JJ217509
# 249119    JJ215813
# 249120    JJ215943
# 249121    JJ215338
# 249122    JJ216668
# Name: Case Number, Length: 249123, dtype: object

# %%
crime['IUCR']
# Out:
# 0         0890
# 1         2825
# 2         0917
# 3         143A
# 4         0890
#           ...
# 249118    2826
# 249119    0430
# 249120    0486
# 249121    0530
# 249122    0710
# Name: IUCR, Length: 249123, dtype: object

# %%
crime['Location Description']
# Out:
# 0                            APARTMENT
# 1         COMMERCIAL / BUSINESS OFFICE
# 2                               STREET
# 3                               STREET
# 4                            RESIDENCE
#                       ...
# 249118                       APARTMENT
# 249119                          STREET
# 249120                       APARTMENT
# 249121                          STREET
# 249122                          STREET
# Name: Location Description, Length: 249123, dtype: object

# %%
crime['Arrest']
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 249118    False
# 249119    False
# 249120    False
# 249121     True
# 249122    False
# Name: Arrest, Length: 249123, dtype: bool

# %%
crime['Community Area']
# Out:
# 0         38.0
# 1         31.0
# 2         23.0
# 3         26.0
# 4         75.0
#           ...
# 249118    22.0
# 249119    49.0
# 249120    71.0
# 249121    61.0
# 249122    28.0
# Name: Community Area, Length: 249123, dtype: float64

# %%
crime['FBI Code']
# Out:
# 0          06
# 1          26
# 2          07
# 3          15
# 4          06
#          ...
# 249118     26
# 249119    04B
# 249120    08B
# 249121    04A
# 249122     06
# Name: FBI Code, Length: 249123, dtype: object

# %%
crime['Location']
# Out:
# 0         (41.821236024, -87.619920712)
# 1         (41.852051675, -87.683800849)
# 2         (41.907640473, -87.735587478)
# 3         (41.877997275, -87.724120826)
# 4           (41.6894214, -87.650123247)
#                       ...
# 249118    (41.928439867, -87.700415972)
# 249119    (41.723545182, -87.632039508)
# 249120     (41.74099774, -87.638606337)
# 249121    (41.802477219, -87.652657244)
# 249122    (41.887694407, -87.657710204)
# Name: Location, Length: 249123, dtype: object

# %% [markdown]
# <h2>Check For Null Values</h2>

# %%
crime.isnull().sum()
# Out:
# ID                        0
# Case Number               0
# Date                      0
# Block                     0
# IUCR                      0
# Primary Type              0
# Description               0
# Location Description    857
# Arrest                    0
# Domestic                  0
# Beat                      0
# District                  0
# Ward                      0
# Community Area            3
# FBI Code                  0
# X Coordinate             90
# Y Coordinate             90
# Year                      0
# Updated On                0
# Latitude                 90
# Longitude                90
# Location                 90
# dtype: int64

# %% [markdown]
# <h2>Fill Null Values with statistical values</h2>

# %%
crime['Location Description'] = crime['Location Description'].fillna('Unknown')

# Fill numeric columns
crime['Community Area'] = crime['Community Area'].fillna(crime['Community Area'].mode()[0])  # use most common value
crime['X Coordinate'] = crime['X Coordinate'].fillna(crime['X Coordinate'].median())
crime['Y Coordinate'] = crime['Y Coordinate'].fillna(crime['Y Coordinate'].median())
crime['Latitude'] = crime['Latitude'].fillna(crime['Latitude'].median())
crime['Longitude'] = crime['Longitude'].fillna(crime['Longitude'].median())

# For 'Location' (string with lat/long)
crime['Location'] = crime['Location'].fillna('(0,0)')

# Convert date columns
crime['Date'] = pd.to_datetime(crime['Date'], errors='coerce')
crime['Updated On'] = pd.to_datetime(crime['Updated On'], errors='coerce')

# Extract new time-based features
crime['year'] = crime['Date'].dt.year
crime['month'] = crime['Date'].dt.month
crime['day'] = crime['Date'].dt.day
crime['dayofweek'] = crime['Date'].dt.day_name()
crime['hour'] = crime['Date'].dt.hour

# Convert selected columns to categorical
categorical_cols = [
    'Primary Type', 'Description', 'Location Description',
    'Arrest', 'Domestic', 'District', 'Ward',
    'Community Area', 'FBI Code', 'year', 'month', 'dayofweek', 'hour'
]

crime['Year'] = crime['Date'].dt.year
crime['Month'] = crime['Date'].dt.month
crime['DayOfWeek'] =crime['Date'].dt.day_name()
crime['Hour'] = crime['Date'].dt.hour

for col in categorical_cols:
    crime[col] = crime[col].astype('category')
    
# Final check (should all be zero)
crime.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# year                    0
# month                   0
# day                     0
# dayofweek               0
# hour                    0
# Month                   0
# DayOfWeek               0
# Hour                    0
# dtype: int64

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# <h2>Question 1. What type of crimes has the most count numbers  </h2>

# %%
plt.subplot()
crime['Primary Type'].value_counts().head(10).plot(kind='bar')
plt.title("Q1: Top 10 Crime Types")
# Out:
# Text(0.5, 1.0, 'Q1: Top 10 Crime Types')

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h2>Theft and battery make up the majority of the dataset. This shows that property crimes and personal conflicts are the most common problems in Chicago..</h2>

# %% [markdown]
# <h2>Question 2.) How fast are crimes growing or declining each year?</h2>

# %%
yearly = crime['Year'].value_counts().sort_index()
plt.figure(figsize=(10,6))
sns.lineplot(x=yearly.index, y=yearly.values, marker="o")
plt.title("Crimes per Year")
plt.xlabel("Year")
plt.ylabel("Number of Crimes")
plt.show()

# %% [markdown]
# <h2>INSIGHTS:</h2>
# <h2>The number of crimes varies. Earlier years had higher counts, while recent years show a clear drop. This suggests that law enforcement and community programs have improved.</h2>

# %% [markdown]
# <h2>Question 3.) Which month records the highest number of crimes?</h2>

# %%
plt.subplot()
crime['Month'].value_counts().sort_index().plot(kind='bar')
plt.title("Q3: Crimes per Month")
# Out:
# Text(0.5, 1.0, 'Q3: Crimes per Month')

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h2>Crimes peak in July. Warmer weather may lead to more social interactions and greater chances for criminal activity.</h2>

# %% [markdown]
# <h2>Question 4.) Which day of the week has the highest number of crimes?</h2>

# %%
days = crime['DayOfWeek'].value_counts()
plt.figure(figsize=(10,6))
sns.barplot(x=days.index, y=days.values,)
plt.title("Crimes by Day of the Week")
plt.xlabel("Day")
plt.ylabel("Number of Crimes")
plt.show()

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h2>Friday consistently shows the highest crime rates. This trend is often connected to weekend social activities.</h2>

# %% [markdown]
# <h2>Question 5.) At what hour of the day do crimes occur most frequently?</h2>

# %%
hours = crime['Hour'].value_counts().sort_index()
plt.figure(figsize=(10,6))
sns.lineplot(x=hours.index, y=hours.values, marker="o", color="red")
plt.title("Crimes by Hour of the Day")
plt.xlabel("Hour")
plt.ylabel("Number of Crimes")
plt.show()

# %% [markdown]
# <h2>INSIGHTS</h2>
# <h2>Crimes peak around 8 PM. This shows that there are higher risks during the evening hours.</h2>

# %%
theft_per_year = crime[crime['Primary Type']=="THEFT"]['Year'].value_counts().sort_index()
plt.figure(figsize=(10,6))
sns.lineplot(x=theft_per_year.index, y=theft_per_year.values, marker="o")
plt.title("Theft Cases by Year")
plt.xlabel("Year")
plt.ylabel("Number of Thefts")
plt.show()

# %% [markdown]
# <h2>Question 6.) Which primary crime type has the highest arrest rate?</h2>

# %%
# Convert Arrest to int (True=1, False=0)
crime['Arrest'] = crime['Arrest'].astype(int)

# Group by crime type and calculate arrest rate
arrest_rate = crime.groupby("Primary Type")['Arrest'].mean().sort_values(ascending=False).head(10)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=arrest_rate.values, y=arrest_rate.index, palette="cividis")
plt.title("Top Crimes by Arrest Rate")
plt.xlabel("Arrest Rate")
plt.ylabel("Crime Type")
plt.show()

# %% [markdown]
# <h2>INSIGHTS:</h2>
# <h2>Drug-related crimes (narcotics) have the highest arrest rates, while property crimes like theft are less often resolved.</h2>

# %% [markdown]
# <h2>Question 7.) Do weekends have higher crime compared to weekdays? </h2>

# %%
crime['IsWeekend'] = crime['DayOfWeek'].isin(["Saturday","Sunday"])
weekend = crime['IsWeekend'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(weekend, labels=['Weekday','Weekend'], autopct='%1.1f%%', colors=["#99ff99","#ff6666"])
plt.title("Weekday vs Weekend Crimes")
plt.show()

# %% [markdown]
# <h2>INSIGHTS: </h2>
# <h2>Weekdays happen to have more crimes in total, but weekends do see a marked surge in violent and public-space crimes.</h2>

# %% [markdown]
# <h2>Question 8.) Which crime types are increasing or decreasing the fastest over the years?</h2>

# %%
crime_trend = crime.groupby(['Year','Primary Type']).size().unstack(fill_value=0)
trend = crime_trend.diff().mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=trend.values, y=trend.index, palette="Spectral")
plt.title("Crimes with Fastest Average Growth/Decline per Year")
plt.xlabel("Average Yearly Change")
plt.ylabel("Crime Type")
plt.show()

# %% [markdown]
# <h2>INSIGHTS:</h2>
# <h2>Crime tends to rise, mostly by assault and weapons violations, whereas certain other sorts, such as drug offences, significantly reduced due to approach changes.</h2>

# %% [markdown]
# <h2>Question 9.) What time of day do robberies peak? </h2>

# %%
robbery_hours = crime[crime['Primary Type']=="ROBBERY"]['Hour'].value_counts().sort_index()

plt.figure(figsize=(10,6))
sns.lineplot(x=robbery_hours.index, y=robbery_hours.values, marker="o", color="brown")
plt.title("Robberies by Hour of Day")
plt.xlabel("Hour")
plt.ylabel("Number of Robberies")
plt.show()

# %% [markdown]
# <h2>INSIGHTS: </h2>
# <h2>Robberies peak in late evening (around 9 PM), consistent with reduced daylight and busier nightlife activity</h2>

# %% [markdown]
# <h2>Question 10.) Which wards report the most crimes?</h2>

# %%
ward_counts = crime['Ward'].value_counts().head(10)
sns.barplot(x=ward_counts.index.astype(str), y=ward_counts.values, palette="mako")
plt.title("Top 10 Wards with the Most Crimes")
plt.xlabel("Ward")
plt.ylabel("Number of Crimes")
plt.show()
ward_counts
# Out:
# Ward
# 27    11622
# 28    11013
# 6      9246
# 42     8721
# 24     8686
# 4      8095
# 20     8037
# 17     7914
# 16     7766
# 21     7480
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHTS: </h2>
# <h2>Wards with high population density or economic disparity tend to show higher crime counts. Identifying these wards helps direct community-based interventions.</h2>

# %% [markdown]
# <h2>Question 11.) What is the arrest rate trend over time?</h2>

# %%
arrest_trend = crime.groupby('Year')['Arrest'].mean()

plt.figure(figsize=(9,5))
sns.lineplot(x=arrest_trend.index, y=arrest_trend.values, marker='o', color='green')
plt.title("Arrest Rate by Year")
plt.xlabel("Year")
plt.ylabel("Arrest Rate (%)")
plt.grid(True)
plt.show()

# %% [markdown]
# <h2>INSIGHTS: </h2>
# <h2>If arrest rates drop, it might mean police are facing resource issues or that more crimes are reported but not solved. If they rise, it could show law enforcement is becoming more effective.</h2>

# %% [markdown]
# <h2>Question 12.) Which locations have the highest number of Theft overall?</h2>

# %%
crime_types = crime[crime["Primary Type"]=="THEFT"]["Location Description"].value_counts()
crime_types
# Out:
# Location Description
# STREET                13185
# APARTMENT              7513
# SMALL RETAIL STORE     6680
# DEPARTMENT STORE       4726
# RESIDENCE              4350
#                       ...
# KENNEL                    0
# NEWSSTAND                 0
# RAILROAD PROPERTY         0
# PORCH                     0
# YARD                      0
# Name: count, Length: 129, dtype: int64

# %% [markdown]
# <h2>INSIGHTS: </h2>
# <h2>It shows that streets have the highest number of thefts because open areas make it easier for someone to commit theft.</h2>

# %% [markdown]
# <h2>Question 13.) Which locations had the highest number of reported crimes each year?</h2>

# %%
# Count crimes at each location per year
location_year = crime.groupby(["Location Description","Year"]).size().reset_index(name="Counts")

# Example: Top 10 locations across all years
top_locations = crime["Location Description"].value_counts().head(10).index
location_year = location_year[location_year["Location Description"].isin(top_locations)]

# Pivot for heatmap
loc_pivot = location_year.pivot(index="Location Description", columns="Year", values="Counts").fillna(0)
loc_pivot
# Out:
# Year                                     2024   2025
# Location Description
# ALLEY                                    4373   1322
# APARTMENT                               35167  12620
# DEPARTMENT STORE                         4202   1566
# OTHER (SPECIFY)                          2990   1082
# PARKING LOT / GARAGE (NON RESIDENTIAL)   6460   1890
# RESIDENCE                               22495   7281
# RESTAURANT                               4593   1501
# SIDEWALK                                10643   2622
# SMALL RETAIL STORE                       7293   2565
# STREET                                  50957  15083

# %% [markdown]
# <h2>INSIGHTS: </h2>
# <h2>“The data shows that streets, homes, and apartments are consistently crime-prone areas. Streets, in particular, remain major hotspots, while changes in other places may be linked to shifts in policing or seasonal factors.”</h2>

# %% [markdown]
# <h2>Question 14.) What are the most common crime types that occur at different locations?</h2>

# %%
# Count crimes at each location by crime type
location_crime = crime.groupby(["Location Description","Primary Type"]).size().reset_index(name="Counts")

# Example: Top 5 locations only
top_locations = crime["Location Description"].value_counts().head(5).index
location_crime = location_crime[location_crime["Location Description"].isin(top_locations)]

# Sort by counts, then take top 20
location_crime = location_crime.sort_values(by="Counts", ascending=False).head(20)
location_crime
# Out:
#      Location Description         Primary Type  Counts
# 498             APARTMENT              BATTERY   14580
# 3550               STREET  MOTOR VEHICLE THEFT   14550
# 3563               STREET                THEFT   13185
# 3539               STREET      CRIMINAL DAMAGE   10334
# 525             APARTMENT                THEFT    7513
# 3071            RESIDENCE              BATTERY    6769
# 3470   SMALL RETAIL STORE                THEFT    6680
# 3536               STREET              BATTERY    6578
# 497             APARTMENT              ASSAULT    5746
# 518             APARTMENT        OTHER OFFENSE    5157
# 501             APARTMENT      CRIMINAL DAMAGE    4896
# 3535               STREET              ASSAULT    4361
# 3098            RESIDENCE                THEFT    4350
# 3091            RESIDENCE        OTHER OFFENSE    4134
# 3556               STREET        OTHER OFFENSE    4114
# 3412             SIDEWALK              BATTERY    3996
# ...

# %% [markdown]
# <h2>INSIGHTS: </h2>
# <h2>“The data shows that theft is most common on streets and in retail stores, while assaults often take place in homes or apartments. This highlights how different crimes are closely tied to the environments where they are most likely to occur.”</h2>

# %% [markdown]
# <h2>QUESTION 15: Which crime types dominate specific community areas? </h2>

# %%
# Count crimes by community area and type
community_crime = crime.groupby(["Community Area","Primary Type"]).size().reset_index(name="Counts")

# Sort and show top 20
community_crime = community_crime.sort_values(by="Counts", ascending=False).head(20)
community_crime
# Out:
#      Community Area     Primary Type  Counts
# 246             8.0            THEFT    4387
# 990            32.0            THEFT    3586
# 866            28.0            THEFT    3215
# 746            25.0          BATTERY    2761
# 184             6.0            THEFT    2683
# 742            24.0            THEFT    2556
# 773            25.0            THEFT    2238
# 680            22.0            THEFT    2009
# 215             7.0            THEFT    1935
# 1304           43.0          BATTERY    1830
# 219             8.0          BATTERY    1534
# 839            28.0          BATTERY    1518
# 870            29.0          BATTERY    1504
# 1331           43.0            THEFT    1443
# 91              3.0            THEFT    1400
# 2110           69.0          BATTERY    1365
# 749            25.0  CRIMINAL DAMAGE    1321
# 2172           71.0          BATTERY    1317
# 684            23.0          BATTERY    1265
# 745            25.0          ASSAULT    1258

# %% [markdown]
# <h2>INSIGHTS: </h2>
# <h2>“Some communities experience certain types of crime more often, which may be influenced by social and economic conditions in those areas.”</h2>
